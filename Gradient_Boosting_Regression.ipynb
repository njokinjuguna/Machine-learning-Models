# %% [markdown]
# <a href="https://colab.research.google.com/github/njokinjuguna/Machine-learning-Models/blob/main/Gradient_Boosting_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data= datasets.load_diabetes()
df=pd.DataFrame(data.data,columns=data.feature_names)
df['traget']=pd.Series(data.target)
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  traget
# ...

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  traget
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  traget  442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 437    False
# 438    False
# 439    False
# 440    False
# 441    False
# Length: 442, dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, sex, bmi, bp, s1, s2, s3, s4, s5, s6, traget]
# Index: []

# %%
y=df['traget']
X=df.drop('traget',axis=1)

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
gbr=GradientBoostingRegressor(n_estimators=500)
gbr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(n_estimators=500)

# %%
y_pred=gbr.predict(X_test)
print(y_pred)
# Out:
# [115.05033434 179.43800975 140.36715629 109.15055766 181.69618809
#  106.0625327   92.39993273  96.02191061  86.75510798 269.19876397
#  116.81411236 310.96787364 107.04987712 113.06329695 151.61474104
#  124.34085731 183.27432764 127.43622341  95.70165331 122.75065658
#  117.6028159   91.41643854 178.35648871 152.71318381 124.10910964
#  117.37076791 302.38138304 142.17816125  90.36860246  95.33589544
#   74.25492042 129.57835006  88.81155266 108.39738254 125.68828973
#  187.65881307 120.09003356 203.87957101 154.93256526  81.74624734
#  155.36420047  91.19947523 161.83393799 243.59747448 200.42074125
#  110.64566882 229.50033161  97.51596019 158.79745533 207.6677864
#  151.31898245 204.5622688  163.52297263 251.63994232 139.04708441
#   89.35961126 169.08450331 119.45314007 123.19722125 125.20405366
#  161.09830765 166.82249846 114.26605299  57.56958482  75.80189025
#  271.55751766  94.14244283 227.89453093  96.14580272 123.38783293
# ...

# %%
mae=mean_absolute_error(y_pred,y_test)
print(mae)
# Out:
# 49.6629228480698

# %%
feature_scores=pd.Series(gbr.feature_importances_,index=X_train.columns).sort_values(ascending=False)
print(feature_scores)
# Out:
# s5     0.335295
# bmi    0.262626
# bp     0.103901
# s2     0.072114
# s6     0.060471
# age    0.054871
# s3     0.049591
# s1     0.032444
# s4     0.014442
# sex    0.014245
# dtype: float64

# %%
sns.barplot(x=feature_scores,y=feature_scores.index)
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.show()
